# %%
cd/content/drive/MyDrive/python
# Out:
# /content/drive/MyDrive/python

# %%
# !git clone https://ttma333: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@github.com/ttma333/python.git
# Out:
# Cloning into 'python'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !git config --global user.email 'ttma998877@gmail.com'
# !git config --global user.name 'ttma333'

# %%
pwd
# Out:
# '/content/drive/MyDrive/python/python'

# %%
# %cd /content/drive/MyDrive/python/python
# Out:
# /content/drive/MyDrive/python/python

# %%
# !git add 깃허브연동.ipynb

# %%
# !git commit -m '깃허브 코랩 연동'
# !git push
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	"\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263\341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274.ipynb"
#
# nothing added to commit but untracked files present
# Everything up-to-date
