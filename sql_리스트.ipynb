# %% [markdown]
# <a href="https://colab.research.google.com/github/ttma333/python/blob/main/sql_%EB%A6%AC%EC%8A%A4%ED%8A%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pwd
# Out:
# '/content'

# %%
cd/content/drive/MyDrive/SQL/mappers
# Out:
# /content/drive/MyDrive/SQL/mappers

# %%
import pandas as pd

# %%
import os
list = ['interest','job','map','member','video']
for i in list:
  path = f'/content/drive/MyDrive/SQL/mappers/{i}'
  file_list = os.listdir(path)
  abc = globals()[f'file_list_{i}'] = [file for file in file_list if file.endswith('.xml')] 
  for j,p in zip(abc,range(1,len(abc)+1)):
    basename = os.path.basename(f'{i}/{j}')
    name ,ext = os.path.splitext(basename)
    globals()[f'_{p}_{i}_{name}'] = pd.read_xml(f'{i}/{j}')

# %%
_1_member_MemberMapper
# Out:
#                              id                          parameterType  \
# 0                    loginCheck                                 string
# 1                  insertMember  com.jobdongsan.project.model.MemberVO
# 2             insertOauthMember  com.jobdongsan.project.model.MemberVO
# 3                    checkMemId                                 String
# 4                 getMemberInfo                                 String
# 5                   mypageCheck                                 String
# 6                 checkMemEmail                                 String
# 7                     findMemId                                 String
# 8                   updateMemPw                                HashMap
# 9              updateMemberInfo  com.jobdongsan.project.model.MemberVO
# 10                 checkMemInfo                                HashMap
# 11                 deleteMember                                 String
# ...
